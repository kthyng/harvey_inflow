# %% [markdown]
# # Run all notebooks
#
# Run all notebooks in correct order.

# %%
# %run ./0_process_bathymetry.ipynb
# Out:
# 44.982302479 51.2904789579
# Full bay area: 1393 km^2, average depth: 3.65 m, volume: 5.09 km^3
# Main bay area: 1190 km^2, average depth: 2.48 m, volume: 2.95 km^3
# West bay area: 202 km^2, average depth: 1.51 m, volume: 0.31 km^3
# The West Bay volume is  6% of the full bay volume
# Average cross-channel depth: 11.3m
# Cross-channel distance: 2.3km
# Constant cross-sectional area: 25738 m^2

# %%
# %run ./1_gather_data.ipynb
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/cart/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~/miniconda3/envs/cart/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [Along [cm/s]] is not in the [columns]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/Documents/papers/inprogress/harvey_inflow/code/notebooks/1_gather_data.ipynb in <module>()
#      48
# ...

# %%
# %run ./2_data_description.ipynb
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/cart/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '8771486: East [m/s]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# %run ./3_calculation.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Documents/papers/inprogress/harvey_inflow/code/notebooks/3_calculation.ipynb in <module>()
#       5
#       6 V = (Am * (Hm + df['%s: Water Level [m, MHW]' % eta_main])) + (Aw * (Hw + df['%s: Water Level [m, MHW]' % eta_west]))
# ----> 7 dVdt = (V.diff()/dt).rolling(center=True, window=4*3).mean()
#
# NameError: name 'dt' is not defined
